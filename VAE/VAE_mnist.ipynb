# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import keras

from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model


original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 2

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)

# %%
from keras import backend as K

def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=100,
        batch_size=32,
        validation_data=(x_test, x_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Epoch 1/100
# 1875/1875 [==============================] - 11s 4ms/step - loss: 186.7881 - val_loss: 166.9800
# Epoch 2/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 165.3241 - val_loss: 163.4957
# Epoch 3/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 162.2867 - val_loss: 161.9011
# Epoch 4/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 160.3891 - val_loss: 159.9962
# Epoch 5/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 158.6839 - val_loss: 158.3909
# Epoch 6/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 157.2172 - val_loss: 157.1418
# Epoch 7/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 156.0230 - val_loss: 155.9329
# Epoch 8/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 155.1028 - val_loss: 155.4175
# Epoch 9/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 154.3545 - val_loss: 154.8918
# Epoch 10/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 153.7365 - val_loss: 154.1562
# Epoch 11/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 153.2147 - val_loss: 153.6821
# Epoch 12/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 152.7702 - val_loss: 153.3533
# Epoch 13/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 152.3804 - val_loss: 153.0077
# Epoch 14/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 152.0119 - val_loss: 152.6078
# Epoch 15/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 151.6933 - val_loss: 152.3149
# Epoch 16/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 151.3639 - val_loss: 152.1798
# Epoch 17/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 151.0756 - val_loss: 151.9894
# Epoch 18/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 150.8206 - val_loss: 151.5400
# Epoch 19/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 150.5795 - val_loss: 151.3887
# Epoch 20/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 150.3506 - val_loss: 151.1426
# Epoch 21/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 150.1105 - val_loss: 151.0033
# Epoch 22/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 149.8957 - val_loss: 150.6853
# Epoch 23/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 149.6759 - val_loss: 150.6531
# Epoch 24/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 149.4995 - val_loss: 150.3757
# Epoch 25/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 149.2699 - val_loss: 150.2404
# Epoch 26/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 149.0913 - val_loss: 150.0309
# Epoch 27/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 148.8921 - val_loss: 149.8428
# Epoch 28/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 148.7186 - val_loss: 149.8955
# Epoch 29/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 148.5537 - val_loss: 149.6502
# Epoch 30/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 148.3695 - val_loss: 149.5845
# Epoch 31/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 148.2235 - val_loss: 149.3457
# Epoch 32/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 148.0822 - val_loss: 149.1237
# Epoch 33/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 147.8967 - val_loss: 149.0187
# Epoch 34/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 147.7634 - val_loss: 148.9235
# Epoch 35/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 147.5956 - val_loss: 148.8512
# Epoch 36/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 147.5005 - val_loss: 148.6185
# Epoch 37/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 147.3523 - val_loss: 148.5473
# Epoch 38/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 147.1917 - val_loss: 148.5024
# Epoch 39/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 147.0879 - val_loss: 148.4252
# Epoch 40/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 146.9459 - val_loss: 148.4707
# Epoch 41/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 146.8748 - val_loss: 148.2063
# Epoch 42/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 146.7371 - val_loss: 148.1065
# Epoch 43/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 146.6391 - val_loss: 148.0486
# Epoch 44/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 146.5243 - val_loss: 148.1076
# Epoch 45/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 146.4156 - val_loss: 148.0792
# Epoch 46/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 146.3477 - val_loss: 148.1213
# Epoch 47/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 146.2206 - val_loss: 147.5688
# Epoch 48/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 146.1536 - val_loss: 147.7529
# Epoch 49/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 146.0526 - val_loss: 147.6723
# Epoch 50/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 145.9963 - val_loss: 147.6003
# Epoch 51/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.8910 - val_loss: 147.6115
# Epoch 52/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.8073 - val_loss: 147.6399
# Epoch 53/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.7239 - val_loss: 147.6086
# Epoch 54/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 145.6674 - val_loss: 147.7480
# Epoch 55/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.6160 - val_loss: 147.6299
# Epoch 56/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.4948 - val_loss: 147.2228
# Epoch 57/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.4605 - val_loss: 147.2874
# Epoch 58/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.3943 - val_loss: 147.3455
# Epoch 59/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.3395 - val_loss: 147.2986
# Epoch 60/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.2872 - val_loss: 147.1600
# Epoch 61/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.2141 - val_loss: 147.3394
# Epoch 62/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.1676 - val_loss: 147.0828
# Epoch 63/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.1269 - val_loss: 147.3253
# Epoch 64/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 145.0421 - val_loss: 147.0333
# Epoch 65/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.9738 - val_loss: 147.2186
# Epoch 66/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.9473 - val_loss: 146.8502
# Epoch 67/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.8788 - val_loss: 146.9419
# Epoch 68/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.8483 - val_loss: 147.1356
# Epoch 69/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.8044 - val_loss: 146.9174
# Epoch 70/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 144.7388 - val_loss: 146.8766
# Epoch 71/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.6710 - val_loss: 146.7869
# Epoch 72/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.6338 - val_loss: 146.8680
# Epoch 73/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.5882 - val_loss: 146.9063
# Epoch 74/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.5780 - val_loss: 146.7596
# Epoch 75/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.4961 - val_loss: 146.6897
# Epoch 76/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.4578 - val_loss: 146.9109
# Epoch 77/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.4104 - val_loss: 146.5638
# Epoch 78/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.3942 - val_loss: 146.9171
# Epoch 79/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.3466 - val_loss: 146.8733
# Epoch 80/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.3158 - val_loss: 146.8463
# Epoch 81/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.2490 - val_loss: 146.5010
# Epoch 82/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.2225 - val_loss: 146.5978
# Epoch 83/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.1995 - val_loss: 146.5908
# Epoch 84/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.1621 - val_loss: 146.4437
# Epoch 85/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.0922 - val_loss: 146.5067
# Epoch 86/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.0810 - val_loss: 146.3989
# Epoch 87/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.0339 - val_loss: 146.5453
# Epoch 88/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.0151 - val_loss: 146.4325
# Epoch 89/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 143.9633 - val_loss: 146.7793
# Epoch 90/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 143.9461 - val_loss: 146.4433
# Epoch 91/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 143.9247 - val_loss: 146.5946
# Epoch 92/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 143.8944 - val_loss: 146.8232
# Epoch 93/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 143.8542 - val_loss: 146.6230
# Epoch 94/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 143.8133 - val_loss: 146.4762
# Epoch 95/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 143.8140 - val_loss: 146.3325
# Epoch 96/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 143.7829 - val_loss: 146.8675
# Epoch 97/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 143.7133 - val_loss: 146.8143
# Epoch 98/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 143.7076 - val_loss: 146.5058
# Epoch 99/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 143.6680 - val_loss: 146.4819
# Epoch 100/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 143.6417 - val_loss: 146.7054

# %%
x_test_encoded = encoder.predict(x_test, batch_size=2)
plt.figure(figsize=(6, 6))
#plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.scatter(x_test_encoded[:,0],x_test_encoded[:,1] , c=y_test)
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0f52a41f7b8a> in <module>()
#       2 plt.figure(figsize=(6, 6))
#       3 #plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
# ----> 4 plt.scatter(x_test_encoded[:,0],x_test_encoded[:,1] , c=y_test)
#       5 plt.colorbar()
#       6 plt.show()
#
# TypeError: list indices must be integers or slices, not tuple

# %%
len(x_test[:,2])
# Out:
# 10000

# %%
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
